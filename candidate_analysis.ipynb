# %%
import pandas as pd
import numpy as np

# %%
CAND1_PATH = "bianca.csv"
CAND2_PATH = "chumbo.csv"

# %%
candidate1_df = pd.read_csv(CAND1_PATH)
candidate2_df = pd.read_csv(CAND2_PATH)

# %%
cand1 = candidate1_df[["tweet", "sentiment"]]
cand2 = candidate2_df[["tweet", "sentiment"]]

# %%
cand1
# Out:
#                                                    tweet sentiment
# 10227  @BabuSantana ajuda nós a te ajudar pela amor😂😂...  Positivo
# 10228  #EstamosComVoceBabu\n#teambabu\n#babu\n#BBB\n#...  Positivo
# 10229  #EstamosComVoceBabu\n#teambabu\n#babu\n#BBB\n#...  Positivo
# 10230  Por mim tirava esses machos escrotos todos e s...  Negativo
# 10231  Aqui o Instagram de todos: \n\n@biancaandradeo...    Neutro

# %%
sent = filter["sentiment"]

# %%
sent.hist()

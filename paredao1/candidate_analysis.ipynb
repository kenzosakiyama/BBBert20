# %%
import pandas as pd
import numpy as np

# %%
CAND1_PATH = "bianca.csv"
CAND2_PATH = "chumbo.csv"

# %%
candidate1_df = pd.read_csv(CAND1_PATH)
candidate2_df = pd.read_csv(CAND2_PATH)

# %%
cand1 = candidate1_df[["tweet", "sentiment"]]
cand2 = candidate2_df[["tweet", "sentiment"]]

# %% [markdown]
# # Bianca

# %%
cand1["sentiment"].hist()

# %%
cand1
# Out:
#                                                    tweet sentiment
# 0                                         Maravilhosa❤❤❤  Positivo
# 1                                              linda! ♥️  Positivo
# 2      Só não ta crescendo no Instagram né 😩 Espero q...  Negativo
# 3              Linda de todo jeito, olha essa barrigaa 🆘  Positivo
# 4                                       EEEEEEEEEEEEEEEE  Positivo
# ...                                                  ...       ...
# 88467  Sim!! Vocês querem que a gente ajude a @BiaAnd...    Neutro
# 88468  @BiaAndradeOfc livra petrix de ser expulso e e...  Negativo
# 88469                           Chumbooooo tem que vazar  Negativo
# 88470  Amooooo a Rafa! Kkkkkk quero saber o voto da @...  Positivo
# 88471        #FICABIANCA #REDEBBB #BBB20\n@BiaAndradeOfc    Neutro
#
# [88472 rows x 2 columns]

# %% [markdown]
# # Chumbo (Eliminado)

# %%
cand2["sentiment"].hist()

# %%
cand2
# Out:
#                                                    tweet sentiment
# 0             Só esperando o @lucaschumbo  ser eliminado  Negativo
# 1      #ficachumbo vamos votar genteeee 🏄🏻‍♂️🏄🏻‍♂️🏄🏻‍...  Positivo
# 2                                          Menino tóxico    Neutro
# 3               @lucaschumbo  pic.twitter.com/bhXdgK3e0v    Neutro
# 4      Parece ser irmão eles dois 😱😱 se parecem muito...  Positivo
# ...                                                  ...       ...
# 13903  VAI COMEÇAAAAAAR CARALHOOOOO VEM FOGO NO PARQU...  Positivo
# 13904                                        #ForaChumbo    Neutro
# 13905  ⚠️ ATENÇÃO SE CHUMBO FOR PRO PAREDÃO ⚠️\nSe LI...  Positivo
# 13906                      Chumbo e vamos de #ForaChumbo    Neutro
# 13907                              #ForaChumbo com força    Neutro
#
# [13908 rows x 2 columns]

# %%
import pandas as pd
import numpy as np
from analysis_utils import *

# %%
PAREDAO = "paredao12"
CAND1_PATH = "data/paredao12/babu.csv"
CAND2_PATH = "data/paredao12/flay.csv"
CAND3_PATH = "data/paredao12/marcela.csv"
DATE = 3
IGNORE_HASHTAGS = ["#bbb20", "#redebbb", "#bbb2020"]

# %%
candidate1_df = pd.read_csv(CAND1_PATH)
candidate2_df = pd.read_csv(CAND2_PATH)
candidate3_df = pd.read_csv(CAND3_PATH)

# %%
cand1 = candidate1_df[["tweet", "sentiment", "date", "likes_count", "retweets_count", "hashtags"]]
cand2 = candidate2_df[["tweet", "sentiment", "date", "likes_count", "retweets_count", "hashtags"]]
cand3 = candidate3_df[["tweet", "sentiment", "date", "likes_count", "retweets_count", "hashtags"]]

# %% [markdown]
# # Babu

# %%
cand1["sentiment"].hist()

# %%
cand1
# Out:
#                                                     tweet sentiment  \
# 0       @RodrigoMaia, @Joao_Almirante e @BabuSantana s...    Neutro
# 1       Minha final 🖤 @manugavassi @thelminha_assis @B...  Positivo
# 2       Vc q gosta da Mari,me explica qual a necessida...  Negativo
# 3       Gabigol vai no Vidigal com o babu quando ele s...    Neutro
# 4                                           @claudiof1lh0    Neutro
# ...                                                   ...       ...
# 109683  Vamos ter que aguentar a insuportável da Flay,...  Negativo
# 109684  Marcela falando que só não votou na Rafa pq se...    Neutro
# 109685  Ivy dizendo que morre de dó de votar no Babu, ...  Negativo
# 109686  o combinado é a marcela saindo em um paredão c...  Negativo
# 109687  Ivy não precisa ter dó do Babu, o que é dele t...    Neutro
#
#               date  likes_count  retweets_count  \
# 0       2020-04-07            2               0
# 1       2020-04-07            2               0
# 2       2020-04-07            3               0
# 3       2020-04-07            2               0
# 4       2020-04-07            1               0
# ...            ...          ...             ...
# 109683  2020-04-05            0               0
# 109684  2020-04-05            1               0
# 109685  2020-04-05            0               0
# 109686  2020-04-05            0               0
# 109687  2020-04-05            0               0
#
#                                           hashtags
# 0                                               []
# 1                                               []
# 2                                               []
# 3                                               []
# 4                                               []
# ...                                            ...
# 109683                                  ['#bbb20']
# 109684                                  ['#bbb20']
# 109685                                  ['#bbb20']
# 109686                                  ['#bbb20']
# 109687  ['#bbb20', '#foramarcela', '#babucampeao']
#
# [109688 rows x 6 columns]

# %% [markdown]
# # Flay

# %%
cand2["sentiment"].hist()

# %%
cand2
# Out:
#                                                    tweet sentiment  \
# 0      Não sou a mãe , mais sim 2 parcial seguida q t...  Negativo
# 1      Esses biscoiteiros que vem só pra procurar vis...  Negativo
# 2        @vxferrari não desanime minha pequena guerreira  Positivo
# 3      Esse fdp do Pyong colocou vcs pra ver BBB...kk...  Negativo
# 4      Por chamar de planta?\nEla pode ser azul, amar...    Neutro
# ...                                                  ...       ...
# 95807  gente a flay precisa sair nesse paredão senhoo...  Negativo
# 95808  O TAPA NA CARA DA FLAY #BBB20  pic.twitter.com...    Neutro
# 95809  INDEPENDENTE, SE A IVY FOR TIREM A FLAY CACETE...  Negativo
# 95810  AF EU QUERIA Q A FLAY SAÍSSE NESSE LOGO INFERN...  Negativo
# 95811  e vamos do discurso da thelma pisando na flay ...  Positivo
#
#              date  likes_count  retweets_count    hashtags
# 0      2020-04-07            1               0          []
# 1      2020-04-07            2               0          []
# 2      2020-04-07            1               0          []
# 3      2020-04-07            0               0          []
# 4      2020-04-07            3               0          []
# ...           ...          ...             ...         ...
# 95807  2020-04-05            3               0  ['#bbb20']
# 95808  2020-04-05            5               1  ['#bbb20']
# 95809  2020-04-05            2               0  ['#bbb20']
# 95810  2020-04-05            9               3  ['#bbb20']
# 95811  2020-04-05           53              12  ['#bbb20']
#
# [95812 rows x 6 columns]

# %% [markdown]
# # Marcela (eliminada)

# %%
cand3["sentiment"].hist()

# %%
cand3
# Out:
#                                                    tweet sentiment  \
# 0      Isso aí Ivy, deixa a Marcela bem arrumada pra ...  Positivo
# 1      Parcial do @guiapureal - 21h\n\nBabu: 0,9%\nFl...    Neutro
# 2      Brasil, meu Brasil, POR FAVOR EU TE IMPLORO, e...  Negativo
# 3      Marcela , vem aqui fora hidratar esse cabelo v...  Positivo
# 4      Parcial Oficial do Detetive \n\n#ForaMarcela  ...    Neutro
# ...                                                  ...       ...
# 69312     Desculpa, Thelma. Mas vai ser a Marcela #BBB20    Neutro
# 69313  Literalmente eles não queriam mais a Marcela n...    Neutro
# 69314  porra, se a Marcela não sair eu não entender l...  Negativo
# 69315  ENQUETE BBB\nQuem sai??\n...\n...\n...\n#bbb #...    Neutro
# 69316  Sério q nessa altura do campeonato a Ivy e Mar...    Neutro
#
#              date  likes_count  retweets_count  \
# 0      2020-04-07            0               0
# 1      2020-04-07          295              33
# 2      2020-04-07            0               0
# 3      2020-04-07            1               0
# 4      2020-04-07          233              34
# ...           ...          ...             ...
# 69312  2020-04-05            2               0
# 69313  2020-04-05            0               0
# 69314  2020-04-05            1               1
# 69315  2020-04-05            0               0
# 69316  2020-04-05            0               0
#
#                                                 hashtags
# 0                                             ['#bbb20']
# 1      ['#bbb20', '#forababu', '#foraflay', '#foramar...
# 2                                             ['#bbb20']
# 3                                             ['#bbb20']
# 4      ['#foramarcela', '#foraflay', '#forababu', '#b...
# ...                                                  ...
# 69312                                         ['#bbb20']
# 69313                                         ['#bbb20']
# 69314                                         ['#bbb20']
# 69315  ['#bbb', '#bbb20', '#redebbb', '#bigbrother', ...
# 69316                             ['#bbb20', '#redebbb']
#
# [69317 rows x 6 columns]

# %% [markdown]
# # Quantidades absolutas

# %%
candidates = {"babu": cand1, "flayslene": cand2, "marcela": cand3}

# %%
qtds_df = get_raw_quantities(candidates)

# %%
qtds_df
# Out:
#            positivos  neutros  negativos
# nome
# babu           29957    32648      47083
# flayslene      20426    24958      50428
# marcela        11371    20025      37921

# %%
qtds_df.plot.bar(rot=45, color=['green', 'gray', 'red'])

# %% [markdown]
# # Porcentagens em relação aos total de tweets de cada candidato

# %%
pcts_df = get_pct_by_candidate(candidates)

# %%
pcts_df
# Out:
#            positivos   neutros  negativos
# nome
# babu        0.273111  0.297644   0.429245
# flayslene   0.213188  0.260489   0.526322
# marcela     0.164043  0.288890   0.547066

# %%
pcts_df.plot.bar(rot=45, color=['green', 'gray', 'red'])

# %% [markdown]
# # Porcentagens em relação ao total de tweets por categoria

# %%
qtds_df_copy = qtds_df.copy()

# %%
qtds_df["positivos"] /= qtds_df["positivos"].sum() 
qtds_df["neutros"] /= qtds_df["neutros"].sum()
qtds_df["negativos"] /= qtds_df["negativos"].sum()

# %%
qtds_df
# Out:
#            positivos   neutros  negativos
# nome
# babu        0.485102  0.420554   0.347650
# flayslene   0.330764  0.321495   0.372349
# marcela     0.184134  0.257951   0.280000

# %%
qtds_df.plot.bar(rot=45, color=['green', 'gray', 'red'])

# %% [markdown]
# # Tweets por dia

# %%
names = list(candidates.keys())
tweets_by_day_df = get_tweets_by_day(candidates[names[0]], names[0])
for name in names[1:]:
    current = get_tweets_by_day(candidates[name], name)
    tweets_by_day_df = tweets_by_day_df.append(current)

# %%
tweets_by_day_df.transpose().plot()

# %% [markdown]
# # Análise de hashtags

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

unique_df = get_unique_hashtags(list(candidates.values()))
unique_df.drop(index=IGNORE_HASHTAGS, inplace=True)
unique_df.sort_values(by="quantidade", ascending=False).head(30).plot.bar(rot=45)

# %%
alias = {"babu": "babu", "flayslene": "flay", "marcela": "marcela"}
fica_fora_df = get_fica_fora_quantities(unique_df, alias)

# %%
fica_fora_df
# Out:
#            fica   fora
# babu       2911   1151
# flayslene  1975  14354
# marcela     449  25937

# %% [markdown]
# # Seleção de atributos

# %%
atributes_df = qtds_df_copy.join(pcts_df, rsuffix="_individual_pct")
atributes_df = atributes_df.join(qtds_df, rsuffix="_global_pct")
atributes_df = atributes_df.join(tweets_by_day_df)
atributes_df = atributes_df.join(fica_fora_df)

# %%
raw_participantes_info = get_participantes_info()[DATE]
print("Seguidores atualizados em:", raw_participantes_info["date"])
# Out:
# Seguidores atualizados em: 10-04-2020

# %%
participantes_info = raw_participantes_info["infos"]
paredoes_info = get_paredoes_info()

# %%
followers = [participantes_info[participante]["seguidores"] for participante in atributes_df.index]

# %%
likes = [get_likes_count(candidates[participante]) for participante in atributes_df.index]

# %%
retweets = [get_retweets_count(candidates[participante]) for participante in atributes_df.index]

# %%
paredao_info = paredoes_info[PAREDAO]["candidatos"]
results_info = {candidate["nome"]: candidate["porcentagem"]/100 for candidate in paredao_info}
rejection = [results_info[participante] for participante in atributes_df.index]

# %%
atributes_df["likes"] = likes
atributes_df["retweets"] = retweets
atributes_df["seguidores"] = followers
atributes_df["rejeicao"] = rejection

# %%
atributes_df
# Out:
#            positivos  neutros  negativos  positivos_individual_pct  \
# nome
# babu           29957    32648      47083                  0.273111
# flayslene      20426    24958      50428                  0.213188
# marcela        11371    20025      37921                  0.164043
#
#            neutros_individual_pct  negativos_individual_pct  \
# nome
# babu                     0.297644                  0.429245
# flayslene                0.260489                  0.526322
# marcela                  0.288890                  0.547066
#
#            positivos_global_pct  neutros_global_pct  negativos_global_pct  \
# nome
# babu                   0.485102            0.420554              0.347650
# flayslene              0.330764            0.321495              0.372349
# marcela                0.184134            0.257951              0.280000
#
#             day1   day2   day3  fica   fora    likes  retweets  seguidores  \
# nome
# babu       21427  62080  26181  2911   1151  3759526    599438      638797
# flayslene  41768  42203  11841  1975  14354  2086839    378441      194492
# marcela    35033  24881   9403   449  25937  1740385    325734      241491
#
#            rejeicao
# nome
# babu         0.0106
# flayslene    0.4918
# marcela      0.4976

# %%
atributes_df.to_csv("data/{}/paredao_atributes.csv".format(PAREDAO))

# %%
import pandas as pd
import numpy as np
from analysis_utils import *

# %%
PAREDAO = "paredao11"
CAND1_PATH = "data/paredao11/babu.csv"
CAND2_PATH = "data/paredao11/gabi.csv"
CAND3_PATH = "data/paredao11/thelma.csv"
DATE = 3
IGNORE_HASHTAGS = ["#bbb20", "#redebbb", "#bbb2020"]

# %%
candidate1_df = pd.read_csv(CAND1_PATH)
candidate2_df = pd.read_csv(CAND2_PATH)
candidate3_df = pd.read_csv(CAND3_PATH)

# %%
cand1 = candidate1_df[["tweet", "sentiment", "date", "likes_count", "retweets_count", "hashtags"]]
cand2 = candidate2_df[["tweet", "sentiment", "date", "likes_count", "retweets_count", "hashtags"]]
cand3 = candidate3_df[["tweet", "sentiment", "date", "likes_count", "retweets_count", "hashtags"]]

# %% [markdown]
# # Babu

# %%
cand1["sentiment"].hist()

# %%
cand1
# Out:
#                                                    tweet sentiment  \
# 0        @BabuSantana  lider  pic.twitter.com/qequLQPrON  Positivo
# 1                   Mobilização geral para o Babu!👊🏿👊🏿👊🏿  Positivo
# 2       E ainda vai usar a torcida do Prior para vencer.    Neutro
# 3      Tomara, mano. Pq essa narrativa canalha das fa...  Negativo
# 4      negro brasileiro. O dominado nada pode impor a...  Negativo
# ...                                                  ...       ...
# 65694  Babu no paredão, quem sera ele vai indicar?? #...    Neutro
# 65695  Tá, Flay desempata mas Babu puxa ela de volta ...    Neutro
# 65696                    q o babu vá na ivy, amém #BBB20  Positivo
# 65697          Poxa Babu e Thelminha no paredao 😭 #bbb20  Positivo
# 65698  Tá vindo Babu x Thelma x Ivy, meu coração não ...  Negativo
#
#              date  likes_count  retweets_count  \
# 0      2020-04-05            0               0
# 1      2020-04-05            2               0
# 2      2020-04-05            1               0
# 3      2020-04-05            0               0
# 4      2020-04-05            0               0
# ...           ...          ...             ...
# 65694  2020-04-03            0               0
# 65695  2020-04-03            1               0
# 65696  2020-04-03            0               0
# 65697  2020-04-03            0               0
# 65698  2020-04-03            1               0
#
#                                   hashtags
# 0                                       []
# 1                                       []
# 2                                       []
# 3                                       []
# 4                                       []
# ...                                    ...
# 65694                           ['#bbb20']
# 65695                           ['#bbb20']
# 65696                           ['#bbb20']
# 65697                           ['#bbb20']
# 65698  ['#redebbb', '#bbb20', '#teambabu']
#
# [65699 rows x 6 columns]

# %% [markdown]
# # Gabi (eliminada)

# %%
cand2["sentiment"].hist()

# %%
cand2
# Out:
#                                                    tweet sentiment  \
# 0                                                    560    Neutro
# 1       https://twitter.com/VaderParciais/status/1246...  Positivo
# 2                                                    750    Neutro
# 3      💜 MUTIRÃO MABI ENCERRADO 💜\n#FORATHELMA ENVIEM...  Negativo
# 4       https://twitter.com/VaderParciais/status/1246...  Positivo
# ...                                                  ...       ...
# 55206                                 Tchau Gabi! #bbb20  Positivo
# 55207                                  Tchau Gabi #BBB20  Positivo
# 55208      Babu chama: Gabi pro paredão. #RedeBBB #BBB20    Neutro
# 55209  E vamos de tendinite pra tirar a gabi #bbb20 #...  Negativo
# 55210        BYE BYE GABI VEM SER SONSA AQUI FORA #BBB20  Positivo
#
#              date  likes_count  retweets_count                hashtags
# 0      2020-04-05            2               0                      []
# 1      2020-04-05            0               0                      []
# 2      2020-04-05            2               0                      []
# 3      2020-04-05          575              35         ['#forathelma']
# 4      2020-04-05            0               0                      []
# ...           ...          ...             ...                     ...
# 55206  2020-04-03            0               0              ['#bbb20']
# 55207  2020-04-03            0               0              ['#bbb20']
# 55208  2020-04-03            0               0  ['#redebbb', '#bbb20']
# 55209  2020-04-03            3               0  ['#bbb20', '#redebbb']
# 55210  2020-04-03            2               0              ['#bbb20']
#
# [55211 rows x 6 columns]

# %% [markdown]
# # Thelma

# %%
cand3["sentiment"].hist()

# %%
cand3
# Out:
#                                                    tweet sentiment  \
# 0      Mais esforço na próxima querida. Essa não eu c...    Neutro
# 1      meu deus mulher te acalma, as pessoas tem vida...  Negativo
# 2                                                    870    Neutro
# 3                                                    210    Neutro
# 4                                                   +100    Neutro
# ...                                                  ...       ...
# 69763  Se o Babu for o mais votado, puxar a Ivy, e Th...    Neutro
# 69764  A Flay tbm ta sendo soberba ou foi só a thelma...    Neutro
# 69765  thelma babu rafa mari #bbb20 manu jikook fanca...  Positivo
# 69766  RAFA E THELMA \nSAIEM DA COMUNIDADE HIPPIE POR...  Negativo
# 69767  Marido de Thelma, do 'BBB20', lista casos de r...    Neutro
#
#              date  likes_count  retweets_count                   hashtags
# 0      2020-04-05            0               0                         []
# 1      2020-04-05            0               0                         []
# 2      2020-04-05            0               0                         []
# 3      2020-04-05            0               0                         []
# 4      2020-04-05            0               0                         []
# ...           ...          ...             ...                        ...
# 69763  2020-04-03            1               0                 ['#bbb20']
# 69764  2020-04-03            1               0  ['#bbb20', '#paredãobbb']
# 69765  2020-04-03            0               0        ['#bbb20', '#kpop']
# 69766  2020-04-03            5               1     ['#bbb20', '#redebbb']
# 69767  2020-04-03            1               0                         []
#
# [69768 rows x 6 columns]

# %% [markdown]
# # Quantidades absolutas

# %%
candidates = {"babu": cand1, "gabi": cand2, "thelma": cand3}

# %%
qtds_df = get_raw_quantities(candidates)

# %%
qtds_df
# Out:
#         positivos  neutros  negativos
# nome
# babu        20279    20221      25199
# gabi        16563    16875      21773
# thelma      17955    24812      27001

# %%
qtds_df.plot.bar(rot=45, color=['green', 'gray', 'red'])

# %% [markdown]
# # Porcentagens em relação aos total de tweets de cada candidato

# %%
pcts_df = get_pct_by_candidate(candidates)

# %%
pcts_df
# Out:
#         positivos   neutros  negativos
# nome
# babu     0.308665  0.307782   0.383552
# gabi     0.299995  0.305646   0.394360
# thelma   0.257353  0.355636   0.387011

# %%
pcts_df.plot.bar(rot=45, color=['green', 'gray', 'red'])

# %% [markdown]
# # Porcentagens em relação ao total de tweets por categoria

# %%
qtds_df_copy = qtds_df.copy()

# %%
qtds_df["positivos"] /= qtds_df["positivos"].sum() 
qtds_df["neutros"] /= qtds_df["neutros"].sum()
qtds_df["negativos"] /= qtds_df["negativos"].sum()

# %%
qtds_df
# Out:
#         positivos   neutros  negativos
# nome
# babu     0.370075  0.326630   0.340651
# gabi     0.302261  0.272582   0.294337
# thelma   0.327664  0.400788   0.365012

# %%
qtds_df.plot.bar(rot=45, color=['green', 'gray', 'red'])

# %% [markdown]
# # Tweets por dia

# %%
names = list(candidates.keys())
tweets_by_day_df = get_tweets_by_day(candidates[names[0]], names[0])
for name in names[1:]:
    current = get_tweets_by_day(candidates[name], name)
    tweets_by_day_df = tweets_by_day_df.append(current)

# %%
tweets_by_day_df.transpose().plot()

# %% [markdown]
# # Análise de hashtags

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

unique_df = get_unique_hashtags(list(candidates.values()))
unique_df.drop(index=IGNORE_HASHTAGS, inplace=True)
unique_df.sort_values(by="quantidade", ascending=False).head(30).plot.bar(rot=45)

# %%
alias = {name: name for name in candidates.keys()}
fica_fora_df = get_fica_fora_quantities(unique_df, alias)

# %%
fica_fora_df
# Out:
#         fica   fora
# babu    4340   1342
# gabi     749  15739
# thelma  6991   5144

# %% [markdown]
# # Seleção de atributos

# %%
atributes_df = qtds_df_copy.join(pcts_df, rsuffix="_individual_pct")
atributes_df = atributes_df.join(qtds_df, rsuffix="_global_pct")
atributes_df = atributes_df.join(tweets_by_day_df)
atributes_df = atributes_df.join(fica_fora_df)

# %%
raw_participantes_info = get_participantes_info()[DATE]
print("Seguidores atualizados em:", raw_participantes_info["date"])
# Out:
# Seguidores atualizados em: 10-04-2020

# %%
participantes_info = raw_participantes_info["infos"]
paredoes_info = get_paredoes_info()

# %%
followers = [participantes_info[participante]["seguidores"] for participante in atributes_df.index]

# %%
likes = [get_likes_count(candidates[participante]) for participante in atributes_df.index]

# %%
retweets = [get_retweets_count(candidates[participante]) for participante in atributes_df.index]

# %%
paredao_info = paredoes_info[PAREDAO]["candidatos"]
results_info = {candidate["nome"]: candidate["porcentagem"]/100 for candidate in paredao_info}
rejection = [results_info[participante] for participante in atributes_df.index]

# %%
atributes_df["likes"] = likes
atributes_df["retweets"] = retweets
atributes_df["seguidores"] = followers
atributes_df["rejeicao"] = rejection

# %%
atributes_df
# Out:
#         positivos  neutros  negativos  positivos_individual_pct  \
# nome
# babu        20279    20221      25199                  0.308665
# gabi        16563    16875      21773                  0.299995
# thelma      17955    24812      27001                  0.257353
#
#         neutros_individual_pct  negativos_individual_pct  \
# nome
# babu                  0.307782                  0.383552
# gabi                  0.305646                  0.394360
# thelma                0.355636                  0.387011
#
#         positivos_global_pct  neutros_global_pct  negativos_global_pct   day1  \
# nome
# babu                0.370075            0.326630              0.340651  34274
# gabi                0.302261            0.272582              0.294337  31402
# thelma              0.327664            0.400788              0.365012  27203
#
#          day2   day3  fica   fora    likes  retweets  seguidores  rejeicao
# nome
# babu    22080   9345  4340   1342  1665136    256280      638797    0.0411
# gabi    15752   8057   749  15739  1077768    170734      237780    0.5961
# thelma  30219  12346  6991   5144  1936851    246960      385019    0.3628

# %%
atributes_df.to_csv("data/{}/paredao_atributes.csv".format(PAREDAO))

# %%
import pandas as pd
import numpy as np
from analysis_utils import *

# %%
PAREDAO = "paredao11"
CAND1_PATH = "data/paredao11/babu.csv"
CAND2_PATH = "data/paredao11/gabi.csv"
CAND3_PATH = "data/paredao11/thelma.csv"

# %%
candidate1_df = pd.read_csv(CAND1_PATH)
candidate2_df = pd.read_csv(CAND2_PATH)
candidate3_df = pd.read_csv(CAND3_PATH)

# %%
cand1 = candidate1_df[["tweet", "sentiment", "date", "likes_count", "retweets_count"]]
cand2 = candidate2_df[["tweet", "sentiment", "date", "likes_count", "retweets_count"]]
cand3 = candidate3_df[["tweet", "sentiment", "date", "likes_count", "retweets_count"]]

# %% [markdown]
# # Babu

# %%
cand1["sentiment"].hist()

# %%
cand1
# Out:
#                                                     tweet sentiment  \
# 0       @RodrigoMaia, @Joao_Almirante e @BabuSantana s...    Neutro
# 1       Minha final 🖤 @manugavassi @thelminha_assis @B...  Positivo
# 2                                    Ok leitora de mentes    Neutro
# 3       Vc q gosta da Mari,me explica qual a necessida...  Negativo
# 4       Gabigol vai no Vidigal com o babu quando ele s...    Neutro
# ...                                                   ...       ...
# 136523  A cara de bosta das meninas pq o babu ficou #B...  Negativo
# 136524  Babu líder ia ser sensacional agora pra mandar...  Positivo
# 136525  Gabi pro Babu: vai com Deus\n\n???? KSKSKSKSKS...    Neutro
# 136526  Babu tem nem o direito de tá com essa cara que...  Negativo
# 136527  A cara da Marcela se dando conta de que o Babu...    Neutro
#
#               date  likes_count  retweets_count
# 0       2020-04-07            2               0
# 1       2020-04-07            2               0
# 2       2020-04-07            0               0
# 3       2020-04-07            3               0
# 4       2020-04-07            2               0
# ...            ...          ...             ...
# 136523  2020-04-05            0               0
# 136524  2020-04-05            0               0
# 136525  2020-04-05            0               0
# 136526  2020-04-05            1               0
# 136527  2020-04-05            3               0
#
# [136528 rows x 5 columns]

# %% [markdown]
# # Gabi (eliminada)

# %%
cand2["sentiment"].hist()

# %%
cand2
# Out:
#                                                    tweet sentiment  \
# 0                                   Saudades Neném!!! ♥️  Negativo
# 1      Desculpa ter achado q a Thelma merecia ficar, ...  Negativo
# 2            👏🏽👏🏽👏🏽👏🏽👏🏽👏🏽👏🏽👏🏽👏🏽👏🏽👏🏽👏🏽👏🏽👏🏽estamos juntas!  Positivo
# 3               RAINHA ACLAMADA CONTE COMIGO PRA TUDOOOO  Positivo
# 4                                           Obrigada 😍😍😍  Positivo
# ...                                                  ...       ...
# 26246           Gabi foi a eliminada da semana no #BBB20    Neutro
# 26247                   Vem chorar aqui fora Gabi #BBB20    Neutro
# 26248                         a Gabi parece eu vey#BBB20  Positivo
# 26249                                   ai gabi 🥺 #BBB20  Positivo
# 26250                 A Gabi kkkkkkkkkkkkkkkkkk \n#BBB20    Neutro
#
#              date  likes_count  retweets_count
# 0      2020-04-07            0               0
# 1      2020-04-07            0               0
# 2      2020-04-07            1               0
# 3      2020-04-07            0               0
# 4      2020-04-07            1               0
# ...           ...          ...             ...
# 26246  2020-04-05            0               0
# 26247  2020-04-05            0               0
# 26248  2020-04-05            0               0
# 26249  2020-04-05            0               0
# 26250  2020-04-05            0               0
#
# [26251 rows x 5 columns]

# %% [markdown]
# # Thelma

# %%
cand3["sentiment"].hist()

# %%
cand3
# Out:
#                                                    tweet sentiment  \
# 0      Minha final 🖤 @manugavassi @thelminha_assis @B...  Positivo
# 1      ela não comparou com o Prior comparou a ATITUD...  Negativo
# 2      Sem xingamentos mas estamos muito tristes em s...  Negativo
# 3      @bbb @rafakalimann_ @thelminha_assis #RedeBBB ...    Neutro
# 4      Não era da Flay , Meu bem, foi uma conversa se...  Negativo
# ...                                                  ...       ...
# 75166    JÁ QUERO THELMA LÍDER E INDICANDO A FLAY #BBB20  Positivo
# 75167  Thelma lider, Flay no paredão, o tombo vem. #B...    Neutro
# 75168  Cada sapo desse que a Thelma jogou foi direto ...  Positivo
# 75169  thelma PERFEITA meteu oitentao na prova se seg...    Neutro
# 75170               jesus ave maria Thelma aaaaaa #bbb20    Neutro
#
#              date  likes_count  retweets_count
# 0      2020-04-07            2               0
# 1      2020-04-07            1               0
# 2      2020-04-07            2               0
# 3      2020-04-07            0               0
# 4      2020-04-07            1               0
# ...           ...          ...             ...
# 75166  2020-04-05            6               0
# 75167  2020-04-05            0               0
# 75168  2020-04-05            5               1
# 75169  2020-04-05            2               0
# 75170  2020-04-05            0               0
#
# [75171 rows x 5 columns]

# %% [markdown]
# # Quantidades absolutas

# %%
candidates = {"babu": cand1, "gabi": cand2, "thelma": cand3}

# %%
qtds_df = get_raw_quantities(candidates)

# %%
qtds_df
# Out:
#         positivos  neutros  negativos
# nome
# babu        37524    41166      57838
# gabi        12734     5007       8510
# thelma      23917    19198      32056

# %%
qtds_df.plot.bar(rot=45, color=['green', 'gray', 'red'])

# %% [markdown]
# # Porcentagens em relação aos total de tweets de cada candidato

# %%
pcts_df = get_pct_by_candidate(candidates)

# %%
pcts_df
# Out:
#         positivos   neutros  negativos
# nome
# babu     0.274845  0.301521   0.423635
# gabi     0.485086  0.190736   0.324178
# thelma   0.318168  0.255391   0.426441

# %%
pcts_df.plot.bar(rot=45, color=['green', 'gray', 'red'])

# %% [markdown]
# # Porcentagens em relação ao total de tweets por categoria

# %%
qtds_df_copy = qtds_df.copy()

# %%
qtds_df["positivos"] /= qtds_df["positivos"].sum() 
qtds_df["neutros"] /= qtds_df["neutros"].sum()
qtds_df["negativos"] /= qtds_df["negativos"].sum()

# %%
qtds_df
# Out:
#         positivos   neutros  negativos
# nome
# babu     0.505885  0.629729   0.587761
# gabi     0.171675  0.076594   0.086480
# thelma   0.322440  0.293678   0.325759

# %%
qtds_df.plot.bar(rot=45, color=['green', 'gray', 'red'])

# %% [markdown]
# # Tweets por dia

# %%
names = list(candidates.keys())
tweets_by_day_df = get_tweets_by_day(candidates[names[0]], names[0])
for name in names[1:]:
    current = get_tweets_by_day(candidates[name], name)
    tweets_by_day_df = tweets_by_day_df.append(current)

# %%
tweets_by_day_df.transpose().plot()

# %% [markdown]
# # Seleção de atributos

# %%
atributes_df = qtds_df_copy.join(pcts_df, rsuffix="_individual_pct")
atributes_df = atributes_df.join(qtds_df, rsuffix="_global_pct")
atributes_df = atributes_df.join(tweets_by_day_df)

# %%
participantes_info = get_participantes_info()
paredoes_info = get_paredoes_info()

# %%
followers = [participantes_info[participante]["seguidores"] for participante in atributes_df.index]

# %%
likes = [get_likes_count(candidates[participante]) for participante in atributes_df.index]

# %%
retweets = [get_retweets_count(candidates[participante]) for participante in atributes_df.index]

# %%
paredao_info = paredoes_info[PAREDAO]["candidatos"]
results_info = {candidate["nome"]: candidate["porcentagem"]/100 for candidate in paredao_info}
rejection = [results_info[participante] for participante in atributes_df.index]

# %%
atributes_df["likes"] = likes
atributes_df["retweets"] = retweets
atributes_df["seguidores"] = followers
atributes_df["rejeicao"] = rejection

# %%
atributes_df
# Out:
#         positivos  neutros  negativos  positivos_individual_pct  \
# nome
# babu        37524    41166      57838                  0.274845
# gabi        12734     5007       8510                  0.485086
# thelma      23917    19198      32056                  0.318168
#
#         neutros_individual_pct  negativos_individual_pct  \
# nome
# babu                  0.301521                  0.423635
# gabi                  0.190736                  0.324178
# thelma                0.255391                  0.426441
#
#         positivos_global_pct  neutros_global_pct  negativos_global_pct   day1  \
# nome
# babu                0.505885            0.629729              0.587761  44496
# gabi                0.171675            0.076594              0.086480  12082
# thelma              0.322440            0.293678              0.325759  35319
#
#          day2   day3    likes  retweets  seguidores  rejeicao
# nome
# babu    64853  27179  4695652    767306      638797    0.0411
# gabi     6797   7372   657616     79477      237780    0.5961
# thelma  28792  11060  1939215    257239      385019    0.3628

# %%
atributes_df.to_csv("data/{}/paredao_atributes.csv".format(PAREDAO))

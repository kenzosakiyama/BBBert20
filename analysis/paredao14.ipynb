# %%
import pandas as pd
import numpy as np
from analysis_utils import *

# %%
PAREDAO = "paredao14"
CAND1_PATH = "data/paredao14/babu.csv"
CAND2_PATH = "data/paredao14/gizelly.csv"
CAND3_PATH = "data/paredao14/mari.csv"
DATE = 3
IGNORE_HASHTAGS = ["#bbb20", "#redebbb", "#bbb2020"]

# %%
candidate1_df = pd.read_csv(CAND1_PATH)
candidate2_df = pd.read_csv(CAND2_PATH)
candidate3_df = pd.read_csv(CAND3_PATH)

# %%
cand1 = candidate1_df[["tweet", "sentiment", "date", "likes_count", "retweets_count", "hashtags"]]
cand2 = candidate2_df[["tweet", "sentiment", "date", "likes_count", "retweets_count", "hashtags"]]
cand3 = candidate3_df[["tweet", "sentiment", "date", "likes_count", "retweets_count", "hashtags"]]

# %% [markdown]
# # Babu

# %%
cand1["sentiment"].hist()

# %%
cand1
# Out:
#                                                     tweet sentiment  \
# 0       Só sei dizer que se @BabuSantana sair hoje, nã...  Negativo
# 1       Se até a Adidas quer, quem é a camelô da Gizel...  Negativo
# 2                                           Só os famosos    Neutro
# 3                                               #ficababu  Positivo
# 4       CHEGAMOS AOS 87 MINUTOS\n\nPARECE QUE TUDO EST...  Negativo
# ...                                                   ...       ...
# 150206  eu nem gosto da Ivy e da Gizelly mas dá pra ve...  Positivo
# 150207  Gizelly perfeita leu jogo todinho do Babu\n#BB...  Positivo
# 150208  O bbb focou na Gizelly dizendo que o babu se f...  Negativo
# 150209  Gizelly lendo o jogo do Babu de vitimista 👏👏👏 ...  Positivo
# 150210  Gizelly falando sobre o Babu mano tô em choque...    Neutro
#
#               date  likes_count  retweets_count  \
# 0       2020-04-14            1               0
# 1       2020-04-14            0               0
# 2       2020-04-14            1               0
# 3       2020-04-14            0               0
# 4       2020-04-14          430              91
# ...            ...          ...             ...
# 150206  2020-04-12            2               1
# 150207  2020-04-12            0               0
# 150208  2020-04-12            3               1
# 150209  2020-04-12            0               0
# 150210  2020-04-12            1               0
#
#                                   hashtags
# 0                                       []
# 1                                       []
# 2                                       []
# 3                            ['#ficababu']
# 4       ['#mutirãoflatt', '#foragizellly']
# ...                                    ...
# 150206                          ['#bbb20']
# 150207              ['#bbb20', '#redebbb']
# 150208                          ['#bbb20']
# 150209                          ['#bbb20']
# 150210                          ['#bbb20']
#
# [150211 rows x 6 columns]

# %% [markdown]
# # Gizelly (eliminada)

# %%
cand2["sentiment"].hist()

# %%
cand2
# Out:
#                                                    tweet sentiment  \
# 0                                               Vamossss  Positivo
# 1                           Não, obrigada! #ForaGizellly  Negativo
# 2                                                   🍀♥️👏  Positivo
# 3                                          Você que lute  Negativo
# 4                                                      👏  Positivo
# ...                                                  ...       ...
# 132617  NAO PORRA PQP VÃO SE LASCAR VCS SÃO MUITO BURROS  Negativo
# 132618                      É FORA MARI VIU SEUS BURROS.  Negativo
# 132619                         NÃO DISCUTE, SÓ VAI VOTAR    Neutro
# 132620                                Tiro no pé isso aí    Neutro
# 132621                   Naooooo adm. Bora de fora Babu.  Negativo
#
#               date  likes_count  retweets_count           hashtags
# 0       2020-04-14            0               0                 []
# 1       2020-04-14            0               0  ['#foragizellly']
# 2       2020-04-14            0               0                 []
# 3       2020-04-14            0               0                 []
# 4       2020-04-14            1               0                 []
# ...            ...          ...             ...                ...
# 132617  2020-04-12            0               0                 []
# 132618  2020-04-12            3               0                 []
# 132619  2020-04-12            0               0                 []
# 132620  2020-04-12            0               0                 []
# 132621  2020-04-12            1               0                 []
#
# [132622 rows x 6 columns]

# %% [markdown]
# # Mari

# %%
cand3["sentiment"].hist()

# %%
cand3
# Out:
#                                                    tweet sentiment  \
# 0                                      Isabella coerente  Positivo
# 1                                                   😍😍😍😍  Positivo
# 2                                             É #ForaBau    Neutro
# 3                                              #ForaBabu  Negativo
# 4                            Se posiciona. Até a ADM é 🌱  Positivo
# ...                                                  ...       ...
# 57683                              Mari eliminada #BBB20    Neutro
# 57684                            Mari eliminada \n#BBB20    Neutro
# 57685  Mari eliminada gente KKKKKKKKKKKKKKKKKKKKKK #B...    Neutro
# 57686                              Mari eliminada #bbb20    Neutro
# 57687                             Mari eliminada  #bbb20    Neutro
#
#              date  likes_count  retweets_count                hashtags
# 0      2020-04-14            0               0                      []
# 1      2020-04-14            0               0                      []
# 2      2020-04-14            0               0            ['#forabau']
# 3      2020-04-14            0               0           ['#forababu']
# 4      2020-04-14            1               0                      []
# ...           ...          ...             ...                     ...
# 57683  2020-04-12            0               0              ['#bbb20']
# 57684  2020-04-12            0               0              ['#bbb20']
# 57685  2020-04-12            0               0  ['#bbb20', '#redebbb']
# 57686  2020-04-12            0               0              ['#bbb20']
# 57687  2020-04-12            0               0              ['#bbb20']
#
# [57688 rows x 6 columns]

# %% [markdown]
# # Quantidades absolutas

# %%
candidates = {"babu": cand1, "gizelly_bicalho": cand2, "mari": cand3}

# %%
qtds_df = get_raw_quantities(candidates)

# %%
qtds_df
# Out:
#                  positivos  neutros  negativos
# nome
# babu                 36145    48034      66032
# gizelly_bicalho      25246    64315      43061
# mari                 14292    18877      24519

# %%
qtds_df.plot.bar(rot=45, color=['green', 'gray', 'red'])

# %% [markdown]
# # Porcentagens em relação aos total de tweets de cada candidato

# %%
pcts_df = get_pct_by_candidate(candidates)

# %%
pcts_df
# Out:
#                  positivos   neutros  negativos
# nome
# babu              0.240628  0.319777   0.439595
# gizelly_bicalho   0.190361  0.484950   0.324690
# mari              0.247746  0.327226   0.425028

# %%
pcts_df.plot.bar(rot=45, color=['green', 'gray', 'red'])

# %% [markdown]
# # Porcentagens em relação ao total de tweets por categoria

# %%
qtds_df_copy = qtds_df.copy()

# %%
qtds_df["positivos"] /= qtds_df["positivos"].sum() 
qtds_df["neutros"] /= qtds_df["neutros"].sum()
qtds_df["negativos"] /= qtds_df["negativos"].sum()

# %%
qtds_df
# Out:
#                  positivos   neutros  negativos
# nome
# babu              0.477584  0.366040   0.494207
# gizelly_bicalho   0.333576  0.490109   0.322284
# mari              0.188840  0.143851   0.183509

# %%
qtds_df.plot.bar(rot=45, color=['green', 'gray', 'red'])

# %% [markdown]
# # Tweets por dia

# %%
names = list(candidates.keys())
tweets_by_day_df = get_tweets_by_day(candidates[names[0]], names[0])
for name in names[1:]:
    current = get_tweets_by_day(candidates[name], name)
    tweets_by_day_df = tweets_by_day_df.append(current)

# %%
tweets_by_day_df.transpose().plot()

# %% [markdown]
# # Análise de hashtags

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

unique_df = get_unique_hashtags(list(candidates.values()))
unique_df.drop(index=IGNORE_HASHTAGS, inplace=True)
unique_df.sort_values(by="quantidade", ascending=False).head(30).plot.bar(rot=45)

# %%
alias = {"babu": "babu", "gizelly_bicalho": "gizelly", "mari": "mari"}
fica_fora_df = get_fica_fora_quantities(unique_df, alias)

# %%
fica_fora_df
# Out:
#                  fica   fora
# babu             4318  20326
# gizelly_bicalho  2279  17902
# mari             1998   2469

# %% [markdown]
# # Seleção de atributos

# %%
atributes_df = qtds_df_copy.join(pcts_df, rsuffix="_individual_pct")
atributes_df = atributes_df.join(qtds_df, rsuffix="_global_pct")
atributes_df = atributes_df.join(tweets_by_day_df)
atributes_df = atributes_df.join(fica_fora_df)

# %%
raw_participantes_info = get_participantes_info()[DATE]
print("Seguidores atualizados em:", raw_participantes_info["date"])
# Out:
# Seguidores atualizados em: 10-04-2020

# %%
participantes_info = raw_participantes_info["infos"]
paredoes_info = get_paredoes_info()

# %%
followers = [participantes_info[participante]["seguidores"] for participante in atributes_df.index]

# %%
likes = [get_likes_count(candidates[participante]) for participante in atributes_df.index]

# %%
retweets = [get_retweets_count(candidates[participante]) for participante in atributes_df.index]

# %%
paredao_info = paredoes_info[PAREDAO]["candidatos"]
results_info = {candidate["nome"]: candidate["porcentagem"]/100 for candidate in paredao_info}
rejection = [results_info[participante] for participante in atributes_df.index]

# %%
atributes_df["likes"] = likes
atributes_df["retweets"] = retweets
atributes_df["seguidores"] = followers
atributes_df["rejeicao"] = rejection

# %%
atributes_df
# Out:
#                  positivos  neutros  negativos  positivos_individual_pct  \
# nome
# babu                 36145    48034      66032                  0.240628
# gizelly_bicalho      25246    64315      43061                  0.190361
# mari                 14292    18877      24519                  0.247746
#
#                  neutros_individual_pct  negativos_individual_pct  \
# nome
# babu                           0.319777                  0.439595
# gizelly_bicalho                0.484950                  0.324690
# mari                           0.327226                  0.425028
#
#                  positivos_global_pct  neutros_global_pct  \
# nome
# babu                         0.477584            0.366040
# gizelly_bicalho              0.333576            0.490109
# mari                         0.188840            0.143851
#
#                  negativos_global_pct   day1   day2   day3  fica   fora  \
# nome
# babu                         0.494207  57766  59614  32831  4318  20326
# gizelly_bicalho              0.322284  14545  77274  40803  2279  17902
# mari                         0.183509  22893  28429   6366  1998   2469
#
#                    likes  retweets  seguidores  rejeicao
# nome
# babu             3730971    617153      638797    0.4133
# gizelly_bicalho   984954    140133      313866    0.5479
# mari              857323     89995      269733    0.0388

# %%
atributes_df.to_csv("data/{}/paredao_atributes.csv".format(PAREDAO))

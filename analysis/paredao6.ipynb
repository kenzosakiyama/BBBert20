# %%
import pandas as pd
import numpy as np
from analysis_utils import *

# %%
PAREDAO = "paredao6"
CAND1_PATH = "data/paredao6/gizelly.csv"
CAND2_PATH = "data/paredao6/guilherme.csv"
CAND3_PATH = "data/paredao6/pyong.csv"
DATE = 2
IGNORE_HASHTAGS = ["#bbb20", "#redebbb", "#bbb2020"]

# %%
candidate1_df = pd.read_csv(CAND1_PATH)
candidate2_df = pd.read_csv(CAND2_PATH)
candidate3_df = pd.read_csv(CAND3_PATH)

# %%
cand1 = candidate1_df[["tweet", "sentiment", "date", "likes_count", "retweets_count", "hashtags"]]
cand2 = candidate2_df[["tweet", "sentiment", "date", "likes_count", "retweets_count", "hashtags"]]
cand3 = candidate3_df[["tweet", "sentiment", "date", "likes_count", "retweets_count", "hashtags"]]

# %% [markdown]
# # Gizelly

# %%
cand1["sentiment"].hist()

# %%
cand1
# Out:
#                                                    tweet sentiment  \
# 0      🦄🌪🎭 MUTIRÃO TRIO DO AMOR ENCERRADO 🦄🌪🎭\n📦 MAND...  Negativo
# 1                        A torcida do Dani está tbem ok!  Positivo
# 2                                    Isso é muiot triste  Negativo
# 3                                                    120    Neutro
# 4                        Meu Deus,queria estar lá tbm ♥️  Positivo
# ...                                                  ...       ...
# 53438  #BBB20 a gizelly disse q o cabelo da flay era ...  Positivo
# 53439  Gizelly tá tão linda, essa mulher não cansa de...  Positivo
# 53440  A mão cai, mas gizelly não sai! 🥇 #BBB20  http...  Negativo
# 53441  Não falou nada sobre o Lucas. Ele apenas reper...  Negativo
# 53442  Ivy indica Gui\nGui puxa Pyong \nCasa indica P...    Neutro
#
#              date  likes_count  retweets_count    hashtags
# 0      2020-03-03          846             116  ['#bbb20']
# 1      2020-03-03            2               1          []
# 2      2020-03-03            0               0          []
# 3      2020-03-03            0               0          []
# 4      2020-03-03            1               0          []
# ...           ...          ...             ...         ...
# 53438  2020-03-01            2               0  ['#bbb20']
# 53439  2020-03-01            3               1  ['#bbb20']
# 53440  2020-03-01            4               0  ['#bbb20']
# 53441  2020-03-01            8               1  ['#bbb20']
# 53442  2020-03-01            3               0  ['#bbb20']
#
# [53443 rows x 6 columns]

# %% [markdown]
# # Guilherme

# %%
cand2["sentiment"].hist()

# %%
cand2
# Out:
#                                                     tweet sentiment  \
# 0       Não sei oq vc tem na cabeça,PQ É CLARO QUE ELE...  Positivo
# 1                                           Foco no Gshow  Positivo
# 2         Sim não parem, não parem de votar no Guilherme.  Negativo
# 3       me convida pro próximo bate papo sobre o bbb @...  Positivo
# 4                                  +2500 votos acumulados    Neutro
# ...                                                   ...       ...
# 102735  - Tiago: Gui quem vc vai imunizar?\n- Gui: Bia...    Neutro
# 102736  Espero que pelo menos uma vez o Guilherme não ...  Negativo
# 102737  Guilherme não espera que Ivy cor nele por favo...  Negativo
# 102738  Ivy vota em Guilherme.\nGuilherme puxa Prior\n...  Positivo
# 102739  Guilherme ja tava pronto pra ficar puto com a ...  Negativo
#
#               date  likes_count  retweets_count  \
# 0       2020-03-03            2               0
# 1       2020-03-03            0               0
# 2       2020-03-03           32               2
# 3       2020-03-03            0               0
# 4       2020-03-03            1               0
# ...            ...          ...             ...
# 102735  2020-03-01            0               0
# 102736  2020-03-01            4               1
# 102737  2020-03-01            0               0
# 102738  2020-03-01            5               0
# 102739  2020-03-01            1               0
#
#                                                  hashtags
# 0                                                      []
# 1                                                      []
# 2                                                      []
# 3                                                      []
# 4                                                      []
# ...                                                   ...
# 102735                                                 []
# 102736  ['#foraguilherme', '#bbb', '#bbb20', '#redebbb...
# 102737                                         ['#bbb20']
# 102738                                         ['#bbb20']
# 102739                                         ['#bbb20']
#
# [102740 rows x 6 columns]

# %% [markdown]
# # Pyong

# %%
cand3["sentiment"].hist()

# %%
cand3
# Out:
#                                                     tweet sentiment  \
# 0       Não vai dar mais se o Pyong for embora 😭😭😭 @Py...  Negativo
# 1       Estou o dia todo votando tem q dar certo meus ...  Positivo
# 2                                   +210 estou na aula :(    Neutro
# 3                  ESQUECE TUDO Q EU DISSE, TE AMO SANTOS  Positivo
# 4       De longe olhando rápido a sua foto do perfil l...    Neutro
# ...                                                   ...       ...
# 114795  Engraçado o povo todo da casa fala mal do pyon...  Negativo
# 114796  Espero que pelo menos uma vez o Guilherme não ...  Negativo
# 114797  Festival de inatividade cerebral: yvi, Gabi, M...  Negativo
# 114798  Ivy vota em Guilherme.\nGuilherme puxa Prior\n...  Positivo
# 114799  Pyong chega a 6,1M no instagram 👏👏👏👏#pyong #TE...  Positivo
#
#               date  likes_count  retweets_count  \
# 0       2020-03-03            0               0
# 1       2020-03-03            0               0
# 2       2020-03-03            0               0
# 3       2020-03-03            0               0
# 4       2020-03-03            1               0
# ...            ...          ...             ...
# 114795  2020-03-01            2               2
# 114796  2020-03-01            4               1
# 114797  2020-03-01            1               0
# 114798  2020-03-01            5               0
# 114799  2020-03-01            5               0
#
#                                                  hashtags
# 0                                      ['#foraguilherme']
# 1                                                      []
# 2                                                      []
# 3                                                      []
# 4                                                      []
# ...                                                   ...
# 114795                                         ['#bbb20']
# 114796  ['#foraguilherme', '#bbb', '#bbb20', '#redebbb...
# 114797                                         ['#bbb20']
# 114798                                         ['#bbb20']
# 114799              ['#pyong', '#teampyonglee', '#bbb20']
#
# [114800 rows x 6 columns]

# %% [markdown]
# # Quantidades absolutas

# %%
candidates = {"gizelly_bicalho": cand1, "guilherme": cand2, "pyong": cand3}

# %%
qtds_df = get_raw_quantities(candidates)

# %%
qtds_df
# Out:
#                  positivos  neutros  negativos
# nome
# gizelly_bicalho      20697    18318      14428
# guilherme            15623    26030      61087
# pyong                24067    31118      59615

# %%
qtds_df.plot.bar(rot=45, color=['green', 'gray', 'red'])

# %% [markdown]
# # Porcentagens em relação aos total de tweets de cada candidato

# %%
pcts_df = get_pct_by_candidate(candidates)

# %%
pcts_df
# Out:
#                  positivos   neutros  negativos
# nome
# gizelly_bicalho   0.387272  0.342758   0.269970
# guilherme         0.152063  0.253358   0.594579
# pyong             0.209643  0.271063   0.519294

# %%
pcts_df.plot.bar(rot=45, color=['green', 'gray', 'red'])

# %% [markdown]
# # Porcentagens em relação ao total de tweets por categoria

# %%
qtds_df_copy = qtds_df.copy()

# %%
qtds_df["positivos"] /= qtds_df["positivos"].sum() 
qtds_df["neutros"] /= qtds_df["neutros"].sum()
qtds_df["negativos"] /= qtds_df["negativos"].sum()

# %%
qtds_df
# Out:
#                  positivos   neutros  negativos
# nome
# gizelly_bicalho   0.342739  0.242732   0.106771
# guilherme         0.258715  0.344924   0.452061
# pyong             0.398546  0.412345   0.441168

# %%
qtds_df.plot.bar(rot=45, color=['green', 'gray', 'red'])

# %% [markdown]
# # Tweets por dia

# %%
names = list(candidates.keys())
tweets_by_day_df = get_tweets_by_day(candidates[names[0]], names[0])
for name in names[1:]:
    current = get_tweets_by_day(candidates[name], name)
    tweets_by_day_df = tweets_by_day_df.append(current)

# %%
tweets_by_day_df.transpose().plot()

# %% [markdown]
# # Análise de hashtags

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

unique_df = get_unique_hashtags(list(candidates.values()))
unique_df.drop(index=IGNORE_HASHTAGS, inplace=True)
unique_df.sort_values(by="quantidade", ascending=False).head(30).plot.bar(rot=45)

# %%
alias = {"gizelly_bicalho": "gizelly", "guilherme": "guilherme", "pyong": "pyong"}
fica_fora_df = get_fica_fora_quantities(unique_df, alias)

# %%
fica_fora_df
# Out:
#                  fica   fora
# gizelly_bicalho  1348    427
# guilherme         244  27184
# pyong            1884  14897

# %% [markdown]
# # Seleção de atributos

# %%
atributes_df = qtds_df_copy.join(pcts_df, rsuffix="_individual_pct")
atributes_df = atributes_df.join(qtds_df, rsuffix="_global_pct")
atributes_df = atributes_df.join(tweets_by_day_df)
atributes_df = atributes_df.join(fica_fora_df)

# %%
raw_participantes_info = get_participantes_info()[DATE]
print("Seguidores atualizados em:", raw_participantes_info["date"])
# Out:
# Seguidores atualizados em: 25-03-2020

# %%
participantes_info = raw_participantes_info["infos"]
paredoes_info = get_paredoes_info()

# %%
followers = [participantes_info[participante]["seguidores"] for participante in atributes_df.index]

# %%
likes = [get_likes_count(candidates[participante]) for participante in atributes_df.index]

# %%
retweets = [get_retweets_count(candidates[participante]) for participante in atributes_df.index]

# %%
paredao_info = paredoes_info[PAREDAO]["candidatos"]
results_info = {candidate["nome"]: candidate["porcentagem"]/100 for candidate in paredao_info}
rejection = [results_info[participante] for participante in atributes_df.index]

# %%
atributes_df["likes"] = likes
atributes_df["retweets"] = retweets
atributes_df["seguidores"] = followers
atributes_df["rejeicao"] = rejection

# %%
atributes_df
# Out:
#                  positivos  neutros  negativos  positivos_individual_pct  \
# nome
# gizelly_bicalho      20697    18318      14428                  0.387272
# guilherme            15623    26030      61087                  0.152063
# pyong                24067    31118      59615                  0.209643
#
#                  neutros_individual_pct  negativos_individual_pct  \
# nome
# gizelly_bicalho                0.342758                  0.269970
# guilherme                      0.253358                  0.594579
# pyong                          0.271063                  0.519294
#
#                  positivos_global_pct  neutros_global_pct  \
# nome
# gizelly_bicalho              0.342739            0.242732
# guilherme                    0.258715            0.344924
# pyong                        0.398546            0.412345
#
#                  negativos_global_pct   day1   day2   day3  fica   fora  \
# nome
# gizelly_bicalho              0.106771  20904  23543   8996  1348    427
# guilherme                    0.452061  49438  35276  18026   244  27184
# pyong                        0.441168  38968  53242  22590  1884  14897
#
#                    likes  retweets  seguidores  rejeicao
# nome
# gizelly_bicalho  2513041    427327      234977    0.0064
# guilherme        2623616    513321      103421    0.5607
# pyong            2790406    500118     1431039    0.4329

# %%
atributes_df.to_csv("data/{}/paredao_atributes.csv".format(PAREDAO))

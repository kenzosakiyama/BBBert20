# %%
import pandas as pd
import numpy as np
from analysis_utils import *

# %%
PAREDAO = "paredao17"
CAND1_PATH = "data/paredao17/babu.csv"
CAND2_PATH = "data/paredao17/rafa.csv"
CAND3_PATH = "data/paredao17/thelma.csv"
DATE = 5
IGNORE_HASHTAGS = ["#bbb20", "#redebbb", "#bbb2020"]

# %%
candidate1_df = pd.read_csv(CAND1_PATH)
candidate2_df = pd.read_csv(CAND2_PATH)
candidate3_df = pd.read_csv(CAND3_PATH)

# %%
cand1 = candidate1_df[["tweet", "sentiment", "date", "likes_count", "retweets_count", "hashtags"]]
cand2 = candidate2_df[["tweet", "sentiment", "date", "likes_count", "retweets_count", "hashtags"]]
cand3 = candidate3_df[["tweet", "sentiment", "date", "likes_count", "retweets_count", "hashtags"]]

# %% [markdown]
# # Babu (eliminado)

# %%
cand1["sentiment"].hist()

# %%
cand1
# Out:
#                                                    tweet sentiment  \
# 0      Gente, em todas as enquetes a rafa tem mais vo...  Negativo
# 1      Também concordo que o Babu foi extremamente im...  Positivo
# 2                                               Lendaaaa    Neutro
# 3      @BabuSantana vacilou em querer proteger a Thel...  Negativo
# 4      Ele gosta de ser professor mas na hora de ser ...    Neutro
# ...                                                  ...       ...
# 84615  MEU DEUS BABU, MAIS AZARADO Q VC SÓ DOIS DE VC...  Negativo
# 84616  BABU NO PAREDÃO, NADA CONTRA BUT SOU #FORABABU...    Neutro
# 84617  Ué mais a prova não era manipulada pro Babu ga...  Negativo
# 84618  PERFEITA MAMÃE, A THELMA TÊM QUE GANHAR ESSA P...  Positivo
# 84619  uai vcs n disseram que o Babu já tinha informa...    Neutro
#
#              date  likes_count  retweets_count                 hashtags
# 0      2020-04-25            0               0            ['#forarafa']
# 1      2020-04-25            0               0                       []
# 2      2020-04-25            0               0                       []
# 3      2020-04-25            0               0                       []
# 4      2020-04-25            1               0                       []
# ...           ...          ...             ...                      ...
# 84615  2020-04-23            0               0               ['#bbb20']
# 84616  2020-04-23            0               0  ['#forababu', '#bbb20']
# 84617  2020-04-23            0               1               ['#bbb20']
# 84618  2020-04-23            1               0               ['#bbb20']
# 84619  2020-04-23            2               0               ['#bbb20']
#
# [84620 rows x 6 columns]

# %% [markdown]
# # Rafa

# %%
cand2["sentiment"].hist()

# %%
cand2
# Out:
#                                                    tweet sentiment  \
# 0                                                    200    Neutro
# 1      Vamos que vamos adm! 👊🏻 Rafa finalista e campe...  Positivo
# 2                        A gente consegue, foco no gshow  Positivo
# 3                                             +320 votos    Neutro
# 4      @thelminha_assis\n@PyongLeeTV @manugavassi\n@r...    Neutro
# ...                                                  ...       ...
# 63735                                          ta maluco  Negativo
# 63736                          Agora não dá, é #ForaBabu  Negativo
# 63737                                          Fora babu  Negativo
# 63738                                          Aí é foda  Positivo
# 63739  @rafakalimann_  e @thelminha_assis  \n\nCadê o...  Negativo
#
#              date  likes_count  retweets_count  \
# 0      2020-04-25            0               0
# 1      2020-04-25            0               0
# 2      2020-04-25            1               0
# 3      2020-04-25            0               0
# 4      2020-04-25            1               1
# ...           ...          ...             ...
# 63735  2020-04-23            0               0
# 63736  2020-04-23            0               0
# 63737  2020-04-23           16               0
# 63738  2020-04-23            0               0
# 63739  2020-04-23            0               0
#
#                                         hashtags
# 0                                             []
# 1                                             []
# 2                                             []
# 3                                             []
# 4      ['#forababu', '#ficathelma', '#ficarafa']
# ...                                          ...
# 63735                                         []
# 63736                              ['#forababu']
# 63737                                         []
# 63738                                         []
# 63739  ['#forababu', '#teamthelma', '#teamrafa']
#
# [63740 rows x 6 columns]

# %% [markdown]
# # Thelma

# %%
cand3["sentiment"].hist()

# %%
cand3
# Out:
#                                                    tweet sentiment  \
# 0      consegui dar +414 antes do gshow me bloquear d...  Negativo
# 1              sem contar adm pic.twitter.com/EyGEf7LEy0    Neutro
# 2                                                    352    Neutro
# 3                                                   +230    Neutro
# 4                                                   +150    Neutro
# ...                                                  ...       ...
# 48876  Gente, alguém tem o vídeo que o babu entrando,...    Neutro
# 48877                            GOGOGOGOG THELMA #bbb20    Neutro
# 48878  thelma finalista\nthelma finalista\nthelma fin...    Neutro
# 48879           As olhadas de Manu pra Rafa kkkkk #BBB20  Positivo
# 48880  Não queria ver Babu hoje no paredão, porque qu...    Neutro
#
#              date  likes_count  retweets_count    hashtags
# 0      2020-04-25            1               0          []
# 1      2020-04-25            1               0          []
# 2      2020-04-25            1               0          []
# 3      2020-04-25            1               0          []
# 4      2020-04-25            1               0          []
# ...           ...          ...             ...         ...
# 48876  2020-04-23            1               0  ['#bbb20']
# 48877  2020-04-23            1               0  ['#bbb20']
# 48878  2020-04-23            3               1  ['#bbb20']
# 48879  2020-04-23            2               0  ['#bbb20']
# 48880  2020-04-23            0               0  ['#bbb20']
#
# [48881 rows x 6 columns]

# %% [markdown]
# # Quantidades absolutas

# %%
candidates = {"babu": cand1, "rafa": cand2, "thelma": cand3}

# %%
qtds_df = get_raw_quantities(candidates)

# %%
qtds_df
# Out:
#         positivos  neutros  negativos
# nome
# babu        20849    25111      38660
# rafa        16158    31861      15721
# thelma      16700    16282      15899

# %%
qtds_df.plot.bar(rot=45, color=['green', 'gray', 'red'])

# %% [markdown]
# # Porcentagens em relação aos total de tweets de cada candidato

# %%
pcts_df = get_pct_by_candidate(candidates)

# %%
pcts_df
# Out:
#         positivos   neutros  negativos
# nome
# babu     0.246384  0.296750   0.456866
# rafa     0.253499  0.499859   0.246643
# thelma   0.341646  0.333095   0.325259

# %%
pcts_df.plot.bar(rot=45, color=['green', 'gray', 'red'])

# %% [markdown]
# # Porcentagens em relação ao total de tweets por categoria

# %%
qtds_df_copy = qtds_df.copy()

# %%
qtds_df["positivos"] /= qtds_df["positivos"].sum() 
qtds_df["neutros"] /= qtds_df["neutros"].sum()
qtds_df["negativos"] /= qtds_df["negativos"].sum()

# %%
qtds_df
# Out:
#         positivos   neutros  negativos
# nome
# babu     0.388199  0.342794   0.550085
# rafa     0.300855  0.434939   0.223691
# thelma   0.310946  0.222268   0.226224

# %%
qtds_df.plot.bar(rot=45, color=['green', 'gray', 'red'])

# %% [markdown]
# # Tweets por dia

# %%
names = list(candidates.keys())
tweets_by_day_df = get_tweets_by_day(candidates[names[0]], names[0])
for name in names[1:]:
    current = get_tweets_by_day(candidates[name], name)
    tweets_by_day_df = tweets_by_day_df.append(current)

# %%
tweets_by_day_df.transpose().plot()

# %% [markdown]
# # Análise de hashtags

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

unique_df = get_unique_hashtags(list(candidates.values()))
unique_df.drop(index=IGNORE_HASHTAGS, inplace=True)
unique_df.sort_values(by="quantidade", ascending=False).head(30).plot.bar(rot=45)

# %%
alias = {name: name for name in candidates.keys()}
fica_fora_df = get_fica_fora_quantities(unique_df, alias)

# %%
fica_fora_df
# Out:
#         fica   fora
# babu    3440  25604
# rafa    4966   4213
# thelma  6564   6057

# %% [markdown]
# # Seleção de atributos

# %%
atributes_df = qtds_df_copy.join(pcts_df, rsuffix="_individual_pct")
atributes_df = atributes_df.join(qtds_df, rsuffix="_global_pct")
atributes_df = atributes_df.join(tweets_by_day_df)
atributes_df = atributes_df.join(fica_fora_df)

# %%
raw_participantes_info = get_participantes_info()[DATE]
print("Seguidores atualizados em:", raw_participantes_info["date"])
# Out:
# Seguidores atualizados em: 2020-04-28 16:28:56.631306

# %%
participantes_info = raw_participantes_info["infos"]
paredoes_info = get_paredoes_info()

# %%
followers = [participantes_info[participante]["seguidores"] for participante in atributes_df.index]

# %%
likes = [get_likes_count(candidates[participante]) for participante in atributes_df.index]

# %%
retweets = [get_retweets_count(candidates[participante]) for participante in atributes_df.index]

# %%
paredao_info = paredoes_info[PAREDAO]["candidatos"]
results_info = {candidate["nome"]: candidate["porcentagem"]/100 for candidate in paredao_info}
rejection = [results_info[participante] for participante in atributes_df.index]

# %%
atributes_df["likes"] = likes
atributes_df["retweets"] = retweets
atributes_df["seguidores"] = followers
atributes_df["rejeicao"] = rejection

# %%
atributes_df
# Out:
#         positivos  neutros  negativos  positivos_individual_pct  \
# nome
# babu        20849    25111      38660                  0.246384
# rafa        16158    31861      15721                  0.253499
# thelma      16700    16282      15899                  0.341646
#
#         neutros_individual_pct  negativos_individual_pct  \
# nome
# babu                  0.296750                  0.456866
# rafa                  0.499859                  0.246643
# thelma                0.333095                  0.325259
#
#         positivos_global_pct  neutros_global_pct  negativos_global_pct   day1  \
# nome
# babu                0.388199            0.342794              0.550085  22285
# rafa                0.300855            0.434939              0.223691  10018
# thelma              0.310946            0.222268              0.226224  20467
#
#          day2   day3  fica   fora    likes  retweets  seguidores  rejeicao
# nome
# babu    36480  25855  3440  25604  1636579    226979      948839    0.5715
# rafa    34744  18978  4966   4213   986666     86307      998093    0.1144
# thelma  10328  18086  6564   6057  1608251    229474      690074    0.3141

# %%
atributes_df.to_csv("data/{}/paredao_atributes.csv".format(PAREDAO))

# %%
import pandas as pd
import numpy as np
from analysis_utils import *

# %%
CAND1_PATH = "data/paredao8/babu.csv"
CAND2_PATH = "data/paredao8/rafa.csv"
CAND3_PATH = "data/paredao8/pyong.csv"

# %%
candidate1_df = pd.read_csv(CAND1_PATH)
candidate2_df = pd.read_csv(CAND2_PATH)
candidate3_df = pd.read_csv(CAND3_PATH)

# %%
cand1 = candidate1_df[["tweet", "sentiment"]]
cand2 = candidate2_df[["tweet", "sentiment"]]
cand3 = candidate3_df[["tweet", "sentiment"]]

# %% [markdown]
# # Babu

# %%
cand1["sentiment"].hist()

# %%
cand1
# Out:
#                                                    tweet sentiment
# 0      Gshow tá lento, isso mostra que tá todo mundo ...  Negativo
# 1                                         Ngm se importa  Negativo
# 2                       Vixe... Se Pyong já estava fu...    Neutro
# 3      Aqui fora ela fez várias amigas íntimas. E eu ...  Negativo
# 4                                                   +300    Neutro
# ...                                                  ...       ...
# 83927  meu deus vai começar hora da corrente de oraçã...    Neutro
# 83928  corrente de oração para o paredão ser entre da...  Positivo
# 83929  Será que vai pro VT a ivysivel falando que tav...    Neutro
# 83930  Apesar de eu achar o Pyong um jogador bem melh...  Positivo
# 83931  Quero a Rafa saindo do Bat e volta e Babu indo...  Negativo
#
# [83932 rows x 2 columns]

# %% [markdown]
# # Rafa

# %%
cand2["sentiment"].hist()

# %%
cand2
# Out:
#                                                    tweet sentiment
# 0                            Vice já me deixa feliz haha  Positivo
# 1                                          Bem mais kkkk  Positivo
# 2                         votando sem contar mas votando    Neutro
# 3      Aproveitando a quarentena e aproveitando a fal...  Negativo
# 4                        estou votando muito sem contar!  Positivo
# ...                                                  ...       ...
# 61594  Não pode excluir o coleguinha viu Manu e Rafa ...    Neutro
# 61595  E hoje o pessoal percebeu como é possível sim ...    Neutro
# 61596  Paredão BBB20: Quem você quer eliminar? Babu, ...    Neutro
# 61597  PELO AMOR DE DEUS GALERA #BBB20  https://twitt...  Positivo
# 61598  A Rafa ainda está chorando ou voltou a falar m...  Negativo
#
# [61599 rows x 2 columns]

# %% [markdown]
# # Pyong (Eliminado)

# %%
cand3["sentiment"].hist()

# %%
cand3
# Out:
#                                                     tweet sentiment
# 0                                      Issoo aiii boraaaa  Positivo
# 1       Sai dai feioso haha tá cobrando quanto pra ass...  Negativo
# 2                                            JÁ, 50 vezes    Neutro
# 3       valeu, arrozin! vai chorar vendo o babu ficand...  Positivo
# 4                          votando sem contar mas votando    Neutro
# ...                                                   ...       ...
# 110300  Não acredito que vai colocar a porra do Pyong ...  Negativo
# 110301                VAI COLOCAR O PYONG PQPPPPPP #BBB20    Neutro
# 110302                         vai indicar o pyong #bbb20    Neutro
# 110303                     #BBB20 burro vai colocar pyong    Neutro
# 110304                         O PYONG NÃO CARALHO #BBB20  Negativo
#
# [110305 rows x 2 columns]

# %% [markdown]
# # Quantidades absolutas

# %%
candidates = {"babu": cand1, "rafa": cand2, "pyong": cand3}

# %%
qtds_df = get_raw_quantities(candidates)

# %%
qtds_df
# Out:
#        positivos  neutros  negativos
# nome
# babu       20043    24848      39041
# rafa       11365    16307      33927
# pyong      23320    37894      49091

# %%
qtds_df.plot.bar(rot=45, color=['green', 'gray', 'red'])

# %% [markdown]
# # Porcentagens em relação aos total de tweets de cada candidato

# %%
pcts_df = get_pct_by_candidate(candidates)

# %%
pcts_df
# Out:
#        positivos   neutros  negativos
# nome
# babu    0.238800  0.296049   0.465150
# rafa    0.184500  0.264728   0.550772
# pyong   0.211414  0.343538   0.445048

# %%
pcts_df.plot.bar(rot=45, color=['green', 'gray', 'red'])

# %% [markdown]
# # Porcentagens em relação ao total de tweets por categoria

# %%
qtds_df["positivos"] /= qtds_df["positivos"].sum() 
qtds_df["neutros"] /= qtds_df["neutros"].sum()
qtds_df["negativos"] /= qtds_df["negativos"].sum()

# %%
qtds_df
# Out:
#        positivos   neutros  negativos
# nome
# babu    0.366229  0.314337   0.319854
# rafa    0.207663  0.206290   0.277956
# pyong   0.426107  0.479374   0.402191

# %%
qtds_df.plot.bar(rot=45, color=['green', 'gray', 'red'])

# %% [markdown]
# # Dados gerais

# %%
final_df = pd.DataFrame(columns=["nome", "qtd_tweets", "positivos", "neutros", "negativos"])

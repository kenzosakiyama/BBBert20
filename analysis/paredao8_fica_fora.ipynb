# %%
import pandas as pd
import numpy as np
from analysis_utils import *

# %%
CAND1_PATH = "data/paredao8/babu_final.csv"
CAND2_PATH = "data/paredao8/rafa_final.csv"
CAND3_PATH = "data/paredao8/pyong_final.csv"

# %%
candidate1_df = pd.read_csv(CAND1_PATH)
candidate2_df = pd.read_csv(CAND2_PATH)
candidate3_df = pd.read_csv(CAND3_PATH)

# %%
cand1 = candidate1_df[["tweet", "sentiment"]]
cand2 = candidate2_df[["tweet", "sentiment"]]
cand3 = candidate3_df[["tweet", "sentiment"]]

# %% [markdown]
# # Babu

# %%
cand1["sentiment"].hist()

# %%
cand1
# Out:
#                                                     tweet sentiment
# 0       quem você quer que saia?\nbabu - fav\npyong - ...  Negativo
# 1       🐻 MUTIRÃO FICA BABU ENCERRADO 🐻\n\n➡ #ForaPyon...  Negativo
# 2       Quem vocês acham que vão sair ?\n\nBabu- Fav ❤...  Negativo
# 3       Quem vocês acham que vão sair ?\n\nBabu- Fav ❤...  Negativo
# 4       Quem vocês acham que vão sair ?\n\nBabu- Fav ❤...  Negativo
# ...                                                   ...       ...
# 242677          Todo apoio ao @BabuSantana \n\n#ForaPyong  Negativo
# 242678          Todo apoio ao @BabuSantana \n\n#ForaPyong  Negativo
# 242679  “DEIXA O BABU FICAR PRO DESESPERO DOS BBB’S"\n...  Negativo
# 242680          Todo apoio ao @BabuSantana \n\n#ForaPyong  Negativo
# 242681       Team babu nesse paredão nós somos #forapyong  Positivo
#
# [242682 rows x 2 columns]

# %% [markdown]
# # Rafa

# %%
cand2["sentiment"].hist()

# %%
cand2
# Out:
#                                                    tweet sentiment
# 0      Esse é o último mutirão, galera! Depois desse ...  Negativo
# 1      Esse é o último mutirão, galera! Depois desse ...  Negativo
# 2      Esse é o último mutirão, galera! Depois desse ...  Negativo
# 3      @PyongLeeTV BORAAAA!!! #FicaRafa #FicaPyong #F...  Negativo
# 4      Esse é o último mutirão, galera! Depois desse ...  Negativo
# ...                                                  ...       ...
# 72686  To com a @rafakalimann_ e com o @BabuSantana  ...    Neutro
# 72687  @rustinpeac @smilerbru @Itspedrito @rafakalima...    Neutro
# 72688  É um paredão difícil pra nós. \nBabu e Pyong s...  Negativo
# 72689              @gizellybicalho_ @rafakalimann_ falsa    Neutro
# 72690  @rafakalimann_ fora pyong vem responder proces...    Neutro
#
# [72691 rows x 2 columns]

# %% [markdown]
# # Pyong (Eliminado)

# %%
cand3["sentiment"].hist()

# %%
cand3
# Out:
#                                                     tweet sentiment
# 0       Pra quem tem a memória curta, pra quem apoia a...    Neutro
# 1             @defantediogo você não era #FicaPyong ?????    Neutro
# 2       @PyongLeeTV BORAAAA!!! #FicaRafa #FicaPyong #F...  Negativo
# 3       @PyongLeeTV BORAAAA!!! #FicaRafa #FicaPyong #F...  Negativo
# 4       Já botei meu irmão p votar tb\n#ForaBabu #Fica...    Neutro
# ...                                                   ...       ...
# 363815  @PyongLeeTV @YgorFremo @biebernovidade\n@biebe...    Neutro
# 363816  @celojpf @afectbitch @PyongLeeTV @Jrcoment Jan...  Positivo
# 363817        @PyongLeeTV Tô torcendo muito por ti Pyoong  Positivo
# 363818  ☯ MUTIRÃO DA MADRUGA! ☯\n\n💪🏻 Foco TOTAL no GS...  Negativo
# 363819  @afectbitch @ALL0W3D @PyongLeeTV E quem disse ...  Negativo
#
# [363820 rows x 2 columns]

# %% [markdown]
# # Quantidades absolutas

# %%
candidates = {"babu": cand1, "rafa": cand2, "pyong": cand3}

# %%
qtds_df = get_raw_quantities(candidates)

# %%
qtds_df
# Out:
#        positivos  neutros  negativos
# nome
# babu       47035    52247     143400
# rafa       21208    18458      33025
# pyong      58194    68263     237363

# %%
qtds_df.plot.bar(rot=45, color=['green', 'gray', 'red'])

# %% [markdown]
# # Porcentagens em relação aos total de tweets de cada candidato

# %%
pcts_df = get_pct_by_candidate(candidates)

# %%
pcts_df
# Out:
#        positivos   neutros  negativos
# nome
# babu    0.193813  0.215290   0.590897
# rafa    0.291756  0.253924   0.454320
# pyong   0.159953  0.187628   0.652419

# %%
pcts_df.plot.bar(rot=45, color=['green', 'gray', 'red'])

# %% [markdown]
# # Porcentagens em relação ao total de tweets por categoria

# %%
qtds_df["positivos"] /= qtds_df["positivos"].sum() 
qtds_df["neutros"] /= qtds_df["neutros"].sum()
qtds_df["negativos"] /= qtds_df["negativos"].sum()

# %%
qtds_df
# Out:
#        positivos   neutros  negativos
# nome
# babu    0.372003  0.375964   0.346554
# rafa    0.167736  0.132822   0.079811
# pyong   0.460261  0.491214   0.573634

# %%
qtds_df.plot.bar(rot=45, color=['green', 'gray', 'red'])

# %% [markdown]
# # Dados gerais

# %%
final_df = pd.DataFrame(columns=["nome", "qtd_tweets", "positivos", "neutros", "negativos"])

# %%
import pandas as pd
import numpy as np

# %%
CAND1_PATH = "babu.csv"
CAND2_PATH = "victor_hugo.csv"
CAND3_PATH = "lucas.csv"

# %%
candidate1_df = pd.read_csv(CAND1_PATH)
candidate2_df = pd.read_csv(CAND2_PATH)
candidate3_df = pd.read_csv(CAND3_PATH)

# %%
cand1 = candidate1_df[["tweet", "sentiment"]]
cand2 = candidate2_df[["tweet", "sentiment"]]
cand3 = candidate3_df[["tweet", "sentiment"]]

# %% [markdown]
# # Babu

# %%
cand1["sentiment"].hist()

# %%
cand1
# Out:
#                                                   tweet sentiment
# 0     Assisti umas 20 vezes, top,um dos melhores fil...  Positivo
# 1          Essa negra linda de Black é à mulher do Babu  Positivo
# 2                Eu acho que fui muito específica 🤷🏾‍♀️  Negativo
# 3                                          Tatiane Melo    Neutro
# 4     Poderia sair 2\n.\n@BabuSantana e Lucas \nSeri...  Positivo
# ...                                                 ...       ...
# 5047            O cara chato mermannnn #BBB2O #ForaBabu  Negativo
# 5048  Gente como alguém tem 1 milhão de seguidores e...  Negativo
# 5049  Babu so cresce p cima da Manu... pq nao fala a...  Negativo
# 5050  Poxa Babu! Respeita a @manugavassi!!! O Babu e...  Positivo
# 5051  que trouxaaaaaa #ForaBabu  https://twitter.com...  Negativo
#
# [5052 rows x 2 columns]

# %% [markdown]
# # Victor Hugo

# %%
cand2["sentiment"].hist()

# %%
cand2
# Out:
#                                                  tweet sentiment
# 0         Essa negra linda de Black é à mulher do Babu  Positivo
# 1               Eu acho que fui muito específica 🤷🏾‍♀️  Negativo
# 2                                         Tatiane Melo    Neutro
# 3                                  Qual o nome dela???    Neutro
# 4    Gente que mulher maravilhosaaaa é essa na foto...  Positivo
# ..                                                 ...       ...
# 800                                        #ForaVictor    Neutro
# 801  #ForaVictor Porque né? Ninguém merece... #Fica...  Negativo
# 802  nesse paredão eu entendi o real significado de...    Neutro
# 803                                 #ForaVictor #BBB20    Neutro
# 804                                        #FORAVICTOR    Neutro
#
# [805 rows x 2 columns]

# %% [markdown]
# # Lucas (Eliminado)

# %%
cand3["sentiment"].hist()

# %%
cand3
# Out:
#                                                    tweet sentiment
# 0      DESCULPE AMIGO , TE RESPEITO MUITO E GOSTO DAS...  Positivo
# 1      Vou continuar  votando , na verdade  eu também...  Negativo
# 2                                       Sdds de Dibella!    Neutro
# 3      Kkkkk empate? Vou correr lá agora e ajudar a d...  Negativo
# 4                                                 flopou    Neutro
# ...                                                  ...       ...
# 30100  Estou agoniada pra vê a formação do paredão, j...  Negativo
# 30101  Lucas tá doido pra sair por isso tá sendo esse...  Negativo
# 30102  Cara hj pensei isso, é um bosta, não faz NADA ...  Negativo
# 30103  #ForaLucas  https://twitter.com/eduucomentou/s...  Positivo
# 30104                                     Sim #foralucas    Neutro
#
# [30105 rows x 2 columns]

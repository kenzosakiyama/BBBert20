# %%
import pandas as pd
import numpy as np

# %%
CAND1_PATH = "prior.csv"
CAND2_PATH = "hadson.csv"

# %%
candidate1_df = pd.read_csv(CAND1_PATH)
candidate2_df = pd.read_csv(CAND2_PATH)

# %%
cand1 = candidate1_df[["tweet", "sentiment"]]
cand2 = candidate2_df[["tweet", "sentiment"]]

# %% [markdown]
# # Felipe Prior

# %%
cand1["sentiment"].hist()

# %%
cand1
# Out:
#                                                   tweet sentiment
# 0                                           chama na DM    Neutro
# 1                                      Prior apaixonado    Neutro
# 2                                          Finalistas 😍  Positivo
# 3     tô votando sem parar. cê pode olhar a dm coisa...  Positivo
# 4               Adoro o Felipe e torço para ele ficar.😍  Positivo
# ...                                                 ...       ...
# 1413  se eu fosse vocês eu tirava o prior dessa vez ...  Negativo
# 1414  olha Brito sinceramente por mim poderia sair o...  Negativo
# 1415  Foi a PRIOR das épocas \n\n#FORAPRIOR #BBBB2O2...    Neutro
# 1416  porque vê ta chorando pombinha\n\n#FORAPRIOR #...  Negativo
# 1417  Gente vcs querem saber como montar um curricul...    Neutro
#
# [1418 rows x 2 columns]

# %% [markdown]
# # Hadson (Eliminado)

# %%
cand2["sentiment"].hist()

# %%
cand2
# Out:
#                                                    tweet sentiment
# 0      QUEM SAI NESSE PAREDÃO ? @felipeprior  ou @Had...  Negativo
# 1             e eu que nem to vendo a hastag #ForaHadson  Negativo
# 2          #ForaHadson #BBB2O pic.twitter.com/2IHftnSoOq    Neutro
# 3      #ForaHadson é sério, porque se não coitada da ...  Negativo
# 4      Vcs estão votando no #ForaHadson ??? Medo dess...  Negativo
# ...                                                  ...       ...
# 10317  Hadson perguntando o contexto de manipulação p...    Neutro
# 10318           #ForaHadson\n pic.twitter.com/zAzrA8fSY9    Neutro
# 10319  E vamos de #ForaHadson com força!!!  https://t...  Positivo
# 10320  Parem de Falar de Victor Hugo e Vamos de #Fora...  Negativo
# 10321  #ForaHadson #forahandson https://twitter.com/t...  Positivo
#
# [10322 rows x 2 columns]
